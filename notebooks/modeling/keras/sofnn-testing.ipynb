# %%
import gc
import time
import keras as k
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import keras.backend as K

from keras import regularizers
from keras.models import Model
from keras.layers import Input, Dense, Lambda
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.metrics import mean_squared_error, \
                confusion_matrix, classification_report

# custom Fuzzy Layers
from sofenn.layers import FuzzyLayer, NormalizedLayer, WeightedLayer

pd.set_option('display.max_columns', None)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Inspecting Data

# %%
df = pd.read_csv('../data/FinalDataset.csv',index_col='date')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1763 entries, 12/27/13 to 10/24/18
# Columns: 132 entries, com_count to bitcoin_market_cap
# dtypes: float64(64), int64(68)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#           com_count  sub_count  com_body_pos_count  com_body_very_pos_count  \
# date
# 12/27/13       6065        477                1516                      766
# 12/28/13       5335        354                1364                      659
# 12/29/13       5413        341                1347                      649
# 12/30/13       5757        447                1547                      783
# 12/31/13       4772        352                1162                      591
#
#           com_body_neg_count  com_body_very_neg_count  sub_body_pos_count  \
# date
# 12/27/13                 666                      253                 105
# 12/28/13                 565                      226                  85
# 12/29/13                 615                      245                  92
# 12/30/13                 659                      277                  96
# 12/31/13                 577                      224                  90
#
#           sub_body_very_pos_count  sub_body_neg_count  \
# date
# 12/27/13                       74                  14
# 12/28/13                       63                  23
# 12/29/13                       67                  17
# 12/30/13                       65                  31
# 12/31/13                       77                  19
#
#           sub_body_very_neg_count  sub_title_pos_count  \
# date
# 12/27/13                        6                   67
# 12/28/13                       14                   54
# 12/29/13                        4                   43
# 12/30/13                       19                   48
# 12/31/13                        7                   50
#
#           sub_title_very_pos_count  sub_title_neg_count  \
# date
# 12/27/13                        10                   22
# 12/28/13                        14                   21
# 12/29/13                        10                   25
# 12/30/13                        14                   27
# 12/31/13                        11                   20
#
#           sub_title_very_neg_count  sub_title_non_zero_pr  \
# date
# 12/27/13                         4                    151
# 12/28/13                         5                    142
# 12/29/13                         3                    134
# 12/30/13                         5                    178
# 12/31/13                         5                    144
#
#           sub_title_top_50_pr  sub_title_top_75_pr  sub_title_pr_4_bins  \
# date
# 12/27/13                   15                    1                96.25
# 12/28/13                   23                    1                72.50
# 12/29/13                   28                    1                69.25
# 12/30/13                   30                    0                92.25
# 12/31/13                   15                    0                67.00
#
#           sub_title_pr_normalized  sub_title_pr_norm_plus_base  \
# date
# 12/27/13                 0.584285                     4.434285
# 12/28/13                 0.643591                     3.543591
# 12/29/13                 0.588035                     3.358035
# 12/30/13                 0.659533                     4.349533
# 12/31/13                 0.474456                     3.154456
#
#           sub_title_pos_non_zero_pr  sub_title_pos_top_50_pr  \
# date
# 12/27/13                         14                        3
# 12/28/13                         20                        5
# 12/29/13                         17                        5
# 12/30/13                         13                        1
# 12/31/13                         17                        3
#
#           sub_title_pos_top_75_pr  sub_title_pos_pr_4_bins  \
# date
# 12/27/13                        0                     13.0
# 12/28/13                        0                     10.5
# 12/29/13                        1                      8.5
# 12/30/13                        0                      8.0
# 12/31/13                        0                      9.0
#
#           sub_title_pos_pr_normalized  sub_title_pos_pr_norm_plus_base  \
# date
# 12/27/13                     0.075103                         0.595103
# 12/28/13                     0.098361                         0.518361
# 12/29/13                     0.147281                         0.487281
# 12/30/13                     0.027653                         0.347653
# 12/31/13                     0.077237                         0.437237
#
#           sub_title_very_pos_non_zero_pr  sub_title_very_pos_top_50_pr  \
# date
# 12/27/13                               1                             0
# 12/28/13                               5                             0
# 12/29/13                               3                             2
# 12/30/13                               2                             0
# 12/31/13                               3                             1
#
#           sub_title_very_pos_top_75_pr  sub_title_very_pos_pr_4_bins  \
# date
# 12/27/13                             0                          1.75
# 12/28/13                             0                          2.50
# 12/29/13                             1                          1.75
# 12/30/13                             0                          2.00
# 12/31/13                             0                          2.00
#
#           sub_title_very_pos_pr_normalized  \
# date
# 12/27/13                          0.000659
# 12/28/13                          0.009961
# 12/29/13                          0.093889
# 12/30/13                          0.001371
# 12/31/13                          0.028142
#
#           sub_title_very_pos_pr_norm_plus_base  sub_title_neg_non_zero_pr  \
# date
# 12/27/13                              0.070659                          9
# 12/28/13                              0.109961                          5
# 12/29/13                              0.163889                         10
# 12/30/13                              0.081371                         17
# 12/31/13                              0.108142                         12
#
#           sub_title_neg_top_50_pr  sub_title_neg_top_75_pr  \
# date
# 12/27/13                        1                        0
# 12/28/13                        0                        0
# 12/29/13                        3                        0
# 12/30/13                        3                        0
# 12/31/13                        0                        0
#
#           sub_title_neg_pr_4_bins  sub_title_neg_pr_normalized  \
# date
# 12/27/13                     4.25                     0.025917
# 12/28/13                     3.25                     0.010043
# 12/29/13                     4.75                     0.060139
# 12/30/13                     6.25                     0.062836
# 12/31/13                     4.00                     0.023762
#
#           sub_title_neg_pr_norm_plus_base  sub_title_very_neg_non_zero_pr  \
# date
# 12/27/13                         0.195917                               1
# 12/28/13                         0.140043                               2
# 12/29/13                         0.250139                               1
# 12/30/13                         0.312836                               3
# 12/31/13                         0.183762                               3
#
#           sub_title_very_neg_top_50_pr  sub_title_very_neg_top_75_pr  \
# date
# 12/27/13                             0                             0
# 12/28/13                             0                             0
# 12/29/13                             1                             0
# 12/30/13                             1                             0
# 12/31/13                             0                             0
#
#           sub_title_very_neg_pr_4_bins  sub_title_very_neg_pr_normalized  \
# date
# 12/27/13                          0.75                          0.000924
# 12/28/13                          1.00                          0.001894
# 12/29/13                          0.50                          0.011801
# 12/30/13                          1.25                          0.008645
# 12/31/13                          1.00                          0.003232
#
#           sub_title_very_neg_pr_norm_plus_base  \
# date
# 12/27/13                              0.030924
# 12/28/13                              0.041894
# 12/29/13                              0.031801
# 12/30/13                              0.058645
# 12/31/13                              0.043232
#
#           sub_title_very_pos_minus_very_neg_non_zero_pr  \
# date
# 12/27/13                                              0
# 12/28/13                                              3
# 12/29/13                                              2
# 12/30/13                                             -1
# 12/31/13                                              0
#
#           sub_title_pos_minus_neg_non_zero_pr  \
# date
# 12/27/13                                    5
# 12/28/13                                   15
# 12/29/13                                    7
# 12/30/13                                   -4
# 12/31/13                                    5
#
#           sub_title_pos_non_zero_pr_percent  \
# date
# 12/27/13                           0.092715
# 12/28/13                           0.140845
# 12/29/13                           0.126866
# 12/30/13                           0.073034
# 12/31/13                           0.118056
#
#           sub_title_very_pos_non_zero_pr_percent  \
# date
# 12/27/13                                0.006623
# 12/28/13                                0.035211
# 12/29/13                                0.022388
# 12/30/13                                0.011236
# 12/31/13                                0.020833
#
#           sub_title_neg_non_zero_pr_percent  \
# date
# 12/27/13                           0.059603
# 12/28/13                           0.035211
# 12/29/13                           0.074627
# 12/30/13                           0.095506
# 12/31/13                           0.083333
#
#           sub_title_very_neg_non_zero_pr_percent  sub_body_non_zero_pr  \
# date
# 12/27/13                                0.006623                   151
# 12/28/13                                0.014085                   142
# 12/29/13                                0.007463                   134
# 12/30/13                                0.016854                   178
# 12/31/13                                0.020833                   144
#
#           sub_body_top_50_pr  sub_body_top_75_pr  sub_body_pr_4_bins  \
# date
# 12/27/13                  15                   1               96.25
# 12/28/13                  23                   1               72.50
# 12/29/13                  28                   1               69.25
# 12/30/13                  30                   0               92.25
# 12/31/13                  15                   0               67.00
#
#           sub_body_pr_normalized  sub_body_pr_norm_plus_base  \
# date
# 12/27/13                0.584285                    4.434285
# 12/28/13                0.643591                    3.543591
# 12/29/13                0.588035                    3.358035
# 12/30/13                0.659533                    4.349533
# 12/31/13                0.474456                    3.154456
#
#           sub_body_pos_non_zero_pr  sub_body_pos_top_50_pr  \
# date
# 12/27/13                        36                       2
# 12/28/13                        27                       4
# 12/29/13                        27                       7
# 12/30/13                        32                       4
# 12/31/13                        35                       2
#
#           sub_body_pos_top_75_pr  sub_body_pos_pr_4_bins  \
# date
# 12/27/13                       0                   21.00
# 12/28/13                       1                   16.75
# 12/29/13                       0                   18.75
# 12/30/13                       0                   20.25
# 12/31/13                       0                   16.50
#
#           sub_body_pos_pr_normalized  sub_body_pos_pr_norm_plus_base  \
# date
# 12/27/13                    0.107567                        0.947567
# 12/28/13                    0.163070                        0.833070
# 12/29/13                    0.112457                        0.862457
# 12/30/13                    0.069699                        0.879699
# 12/31/13                    0.086676                        0.746676
#
#           sub_body_very_pos_non_zero_pr  sub_body_very_pos_top_50_pr  \
# date
# 12/27/13                             27                            1
# 12/28/13                             21                            4
# 12/29/13                             21                            5
# 12/30/13                             20                            3
# 12/31/13                             31                            1
#
#           sub_body_very_pos_top_75_pr  sub_body_very_pos_pr_4_bins  \
# date
# 12/27/13                            0                        14.00
# 12/28/13                            1                        12.50
# 12/29/13                            0                        13.75
# 12/30/13                            0                        13.50
# 12/31/13                            0                        14.25
#
#           sub_body_very_pos_pr_normalized  \
# date
# 12/27/13                         0.072764
# 12/28/13                         0.153450
# 12/29/13                         0.073157
# 12/30/13                         0.054270
# 12/31/13                         0.055899
#
#           sub_body_very_pos_pr_norm_plus_base  sub_body_neg_non_zero_pr  \
# date
# 12/27/13                             0.632764                         2
# 12/28/13                             0.653450                         9
# 12/29/13                             0.623157                         6
# 12/30/13                             0.594270                        10
# 12/31/13                             0.625899                         8
#
#           sub_body_neg_top_50_pr  sub_body_neg_top_75_pr  \
# date
# 12/27/13                       0                       0
# 12/28/13                       1                       0
# 12/29/13                       1                       0
# 12/30/13                       1                       0
# 12/31/13                       1                       0
#
#           sub_body_neg_pr_4_bins  sub_body_neg_pr_normalized  \
# date
# 12/27/13                    2.75                    0.001754
# 12/28/13                    5.00                    0.052546
# 12/29/13                    3.25                    0.015375
# 12/30/13                    5.25                    0.020664
# 12/31/13                    4.25                    0.046963
#
#           sub_body_neg_pr_norm_plus_base  sub_body_very_neg_non_zero_pr  \
# date
# 12/27/13                        0.111754                              1
# 12/28/13                        0.252546                              5
# 12/29/13                        0.145375                              2
# 12/30/13                        0.230664                              7
# 12/31/13                        0.216963                              2
#
#           sub_body_very_neg_top_50_pr  sub_body_very_neg_top_75_pr  \
# date
# 12/27/13                            0                            0
# 12/28/13                            0                            0
# 12/29/13                            0                            0
# 12/30/13                            1                            0
# 12/31/13                            0                            0
#
#           sub_body_very_neg_pr_4_bins  sub_body_very_neg_pr_normalized  \
# date
# 12/27/13                         1.50                         0.001510
# 12/28/13                         3.00                         0.008731
# 12/29/13                         1.00                         0.003103
# 12/30/13                         3.25                         0.019851
# 12/31/13                         1.75                         0.000490
#
#           sub_body_very_neg_pr_norm_plus_base  \
# date
# 12/27/13                             0.061510
# 12/28/13                             0.128731
# 12/29/13                             0.043103
# 12/30/13                             0.149851
# 12/31/13                             0.070490
#
#           sub_body_very_pos_minus_very_neg_non_zero_pr  \
# date
# 12/27/13                                            26
# 12/28/13                                            16
# 12/29/13                                            19
# 12/30/13                                            13
# 12/31/13                                            29
#
#           sub_body_pos_minus_neg_non_zero_pr  \
# date
# 12/27/13                                  34
# 12/28/13                                  18
# 12/29/13                                  21
# 12/30/13                                  22
# 12/31/13                                  27
#
#           sub_body_pos_non_zero_pr_percent  \
# date
# 12/27/13                          0.238411
# 12/28/13                          0.190141
# 12/29/13                          0.201493
# 12/30/13                          0.179775
# 12/31/13                          0.243056
#
#           sub_body_very_pos_non_zero_pr_percent  \
# date
# 12/27/13                               0.178808
# 12/28/13                               0.147887
# 12/29/13                               0.156716
# 12/30/13                               0.112360
# 12/31/13                               0.215278
#
#           sub_body_neg_non_zero_pr_percent  \
# date
# 12/27/13                          0.013245
# 12/28/13                          0.063380
# 12/29/13                          0.044776
# 12/30/13                          0.056180
# 12/31/13                          0.055556
#
#           sub_body_very_neg_non_zero_pr_percent  com_body_non_zero_pr  \
# date
# 12/27/13                               0.006623                  3765
# 12/28/13                               0.035211                  3252
# 12/29/13                               0.014925                  3160
# 12/30/13                               0.039326                  3395
# 12/31/13                               0.013889                  2772
#
#           com_body_top_50_pr  com_body_top_75_pr  com_body_pr_4_bins  \
# date
# 12/27/13                 353                  27             1314.25
# 12/28/13                 313                  15             1142.75
# 12/29/13                 341                  12             1168.50
# 12/30/13                 347                  11             1256.00
# 12/31/13                 217                   6             1027.75
#
#           com_body_pr_normalized  com_body_pr_norm_plus_base  \
# date
# 12/27/13               11.717771                   64.287771
# 12/28/13               10.747918                   56.457918
# 12/29/13               10.297029                   57.037029
# 12/30/13               10.062607                   60.302607
# 12/31/13                7.866991                   48.976991
#
#           com_body_pos_non_zero_pr  com_body_pos_top_50_pr  \
# date
# 12/27/13                      1024                      96
# 12/28/13                       858                      89
# 12/29/13                       854                      94
# 12/30/13                       976                     102
# 12/31/13                       733                      59
#
#           com_body_pos_top_75_pr  com_body_pos_pr_4_bins  \
# date
# 12/27/13                      12                  358.25
# 12/28/13                       5                  319.25
# 12/29/13                       4                  319.25
# 12/30/13                       2                  368.00
# 12/31/13                       3                  275.25
#
#           com_body_pos_pr_normalized  com_body_pos_pr_norm_plus_base  \
# date
# 12/27/13                    3.327513                       17.657513
# 12/28/13                    2.878575                       15.648575
# 12/29/13                    2.755338                       15.525338
# 12/30/13                    2.893901                       17.613901
# 12/31/13                    2.111246                       13.121246
#
#           com_body_very_pos_non_zero_pr  com_body_very_pos_top_50_pr  \
# date
# 12/27/13                            511                           57
# 12/28/13                            422                           53
# 12/29/13                            400                           46
# 12/30/13                            501                           51
# 12/31/13                            362                           28
#
#           com_body_very_pos_top_75_pr  com_body_very_pos_pr_4_bins  \
# date
# 12/27/13                            6                       182.25
# 12/28/13                            4                       155.75
# 12/29/13                            2                       153.75
# 12/30/13                            1                       187.50
# 12/31/13                            2                       140.50
#
#           com_body_very_pos_pr_normalized  \
# date
# 12/27/13                         1.848885
# 12/28/13                         1.549258
# 12/29/13                         1.332019
# 12/30/13                         1.406782
# 12/31/13                         1.136226
#
#           com_body_very_pos_pr_norm_plus_base  com_body_neg_non_zero_pr  \
# date
# 12/27/13                             9.138885                       447
# 12/28/13                             7.779258                       378
# 12/29/13                             7.482019                       394
# 12/30/13                             8.906782                       441
# 12/31/13                             6.756226                       371
#
#           com_body_neg_top_50_pr  com_body_neg_top_75_pr  \
# date
# 12/27/13                      43                       4
# 12/28/13                      40                       1
# 12/29/13                      43                       0
# 12/30/13                      40                       0
# 12/31/13                      24                       0
#
#           com_body_neg_pr_4_bins  com_body_neg_pr_normalized  \
# date
# 12/27/13                   157.0                    1.422873
# 12/28/13                   131.0                    1.458302
# 12/29/13                   142.5                    1.285179
# 12/30/13                   157.0                    1.089178
# 12/31/13                   135.5                    0.880660
#
#           com_body_neg_pr_norm_plus_base  com_body_very_neg_non_zero_pr  \
# date
# 12/27/13                        7.702873                            181
# 12/28/13                        6.698302                            155
# 12/29/13                        6.985179                            156
# 12/30/13                        7.369178                            191
# 12/31/13                        6.300660                            145
#
#           com_body_very_neg_top_50_pr  com_body_very_neg_top_75_pr  \
# date
# 12/27/13                           22                            2
# 12/28/13                           26                            1
# 12/29/13                           20                            0
# 12/30/13                           17                            0
# 12/31/13                            5                            0
#
#           com_body_very_neg_pr_4_bins  com_body_very_neg_pr_normalized  \
# date
# 12/27/13                        60.25                         0.696103
# 12/28/13                        51.00                         0.787010
# 12/29/13                        55.00                         0.597477
# 12/30/13                        66.50                         0.459345
# 12/31/13                        53.50                         0.260187
#
#           com_body_very_neg_pr_norm_plus_base  \
# date
# 12/27/13                             3.106103
# 12/28/13                             2.827010
# 12/29/13                             2.797477
# 12/30/13                             3.119345
# 12/31/13                             2.400187
#
#           com_body_very_pos_minus_very_neg_non_zero_pr  \
# date
# 12/27/13                                           330
# 12/28/13                                           267
# 12/29/13                                           244
# 12/30/13                                           310
# 12/31/13                                           217
#
#           com_body_pos_minus_neg_non_zero_pr  \
# date
# 12/27/13                                 577
# 12/28/13                                 480
# 12/29/13                                 460
# 12/30/13                                 535
# 12/31/13                                 362
#
#           com_body_pos_non_zero_pr_percent  \
# date
# 12/27/13                          0.271979
# 12/28/13                          0.263838
# 12/29/13                          0.270253
# 12/30/13                          0.287482
# 12/31/13                          0.264430
#
#           com_body_very_pos_non_zero_pr_percent  \
# date
# 12/27/13                               0.135724
# 12/28/13                               0.129766
# 12/29/13                               0.126582
# 12/30/13                               0.147570
# 12/31/13                               0.130592
#
#           com_body_neg_non_zero_pr_percent  \
# date
# 12/27/13                          0.118725
# 12/28/13                          0.116236
# 12/29/13                          0.124684
# 12/30/13                          0.129897
# 12/31/13                          0.133838
#
#           com_body_very_neg_non_zero_pr_percent  avg_clust_coef  avg_degree  \
# date
# 12/27/13                               0.048074        0.006916      1.4146
# 12/28/13                               0.047663        0.004497      1.4280
# 12/29/13                               0.049367        0.007134      1.2978
# 12/30/13                               0.056259        0.004985      1.4208
# 12/31/13                               0.052309        0.003238      1.2487
#
#           num_edges  num_nodes  bitcoin_open  bitcoin_high  bitcoin_low  \
# date
# 12/27/13       2856       2019        763.28        777.51       713.60
# 12/28/13       2689       1883        737.98        747.06       705.35
# 12/29/13       2436       1877        728.05        748.61       714.44
# 12/30/13       2762       1944        741.35        766.60       740.24
# 12/31/13       2234       1789        760.32        760.58       738.17
#
#           bitcoin_close  bitcoin_volume  bitcoin_market_cap
# date
# 12/27/13         735.07        46862700        9.295570e+09
# 12/28/13         727.83        32505800        8.990850e+09
# 12/29/13         745.05        19011300        8.872600e+09
# 12/30/13         756.13        20707700        9.037000e+09
# 12/31/13         754.01        20897300        9.268240e+09

# %%
# show closing price time series
df['bitcoin_close'].plot(title='BTC Close Price',grid=True,rot=35, figsize=(12,8))

# %%
# show log-closing price time series
df['bitcoin_close'].plot(title='BTC Log-Close Price',grid=True,logy=True,rot=35, figsize=(12,8))

# %%
# stats on time series length
print("number of days:  {:.1f}".format(df.shape[0]))
print("number of months:  {:.1f}".format(df.shape[0] / 30))
print("number of years:    {:.1f}".format(df.shape[0] / 365))
# Out:
# number of days:  1763.0
# number of months:  58.8
# number of years:    4.8

# %% [markdown]
# # Defining Functions

# %% [markdown]
# ## Loading and Preparing Data

# %%
# function to read in dataset

def get_data():
    return pd.read_csv('../data/FinalDataset.csv',index_col='date')

# %%
# function to drop unneeded fields

def keep_only_close(df_in):
    drops = ['bitcoin_open', 'bitcoin_high', 'bitcoin_low',
             'bitcoin_volume', 'bitcoin_market_cap']
    return df_in.drop(drops, axis=1)

# %%
# function to add predicted column for tomorrow's close price

def add_prediction_field(df_in):
    # creating predicted value
    # create column to hold tomorrow's close for each day
    df_in['tomorrow_close'] = df_in['bitcoin_close'].shift(-1)
    # change in price between consecutive closing days
    df_in['day_change'] = df_in['tomorrow_close'] - df_in['bitcoin_close']
    # indicator variable to be used for predicting higher/lower days
    df_in['y'] = np.where(df_in['day_change'] >= 0, 1, 0)
        
    # drop intermediate columns
    return df_in.drop(['tomorrow_close', 'day_change'], axis=1)

# %%
# function to retrieve lag values to use for each feature

def get_feature_lag_dict(lag_vers=1):
    # check value of input
    if lag_vers not in [1, 2, 3, 4]:
        raise ValueError('Incorrect Version')
    
    # read in right version of file
    df = pd.read_csv('../lags/optimal_v{}.csv'.format(lag_vers))
    
    # return dictionary of features as keys and lags as values
    return dict(zip(df.feature, df.lags))

# %%
# function to add lags for daily features

def add_lags(df_in, lag_vers=1):
    # splitting into X/y for separate processing
    X, y = df_in[df_in.columns[:-1]], df_in[df_in.columns[-1]]
    # save list of columns for lags
    col_list = X.columns
    # create output DF
    df_out = X.copy()
    
    # creating lags
    f_dict = get_feature_lag_dict(lag_vers=lag_vers)
    # create lag columns for each other variable
    for col in col_list:
        if col not in f_dict.keys(): continue
        for lag in range(int(f_dict[col])):
            df_out['{}_(-{})'.format(col,lag+1)] = df_out[col].shift(lag+1)

    # return and drop na
    df_out['y'] = y
    return df_out.dropna()

# %%
# function to remove data before certain date

def truncate_date(df_in, first_day='1999-1-1'):
    # set mask of Bool values
    mask = (pd.to_datetime(df_in.index) >= first_day)
    return df_in.loc[mask]

# %%
# function to rejoin training data into X/y again

def rejoin_training_data(X_train, X_test, y_train, y_test):
    Xs = [X_train, X_test]
    Ys = [y_train, y_test]
    
    df_out = pd.concat(Xs)
    df_out['y'] = pd.concat(Ys)
    
    return df_out

# %%
# function to create train/test X and y
def create_training_data(df_in, lag_vers=1, train_split=0.7, rescale=True, k_feat_perc=None):
    # split into test train
    X, y = df_in[df_in.columns[:-1]], df_in[df_in.columns[-1]]
    
    # determine cutoff of train/test split and split
    cutoff = int(X.shape[0] * train_split)
    X_train, y_train = X[:cutoff], y[:cutoff]
    X_test, y_test = X[cutoff:], y[cutoff:]
    
    # scale values to 0-1
    # must only scale based on training data, to ensure no 
    # foresight with averages
    if rescale:
        scaler = MinMaxScaler(feature_range=(0,1)).fit(X_train.values)
        cols = X.columns
        X_train = pd.DataFrame(scaler.transform(X_train.values), 
                               index=X_train.index, columns=cols)
        X_test = pd.DataFrame(scaler.transform(X_test.values), 
                               index=X_test.index, columns=cols)
    
    # select top K features to use
    if k_feat_perc:
        selector = SelectPercentile(chi2, percentile=k_feat_perc).fit(
                                    X_train.values,y_train.values)
        # index and names of remainig columns after filter
        cols = X_train.columns[selector.get_support(indices = True)]
        X_train = pd.DataFrame(selector.transform(X_train.values), 
                               index=X_train.index, columns=cols)
        X_test = pd.DataFrame(selector.transform(X_test.values), 
                               index=X_test.index, columns=cols)
    
    # recreate into X/y DF and add lags
    df_renew = rejoin_training_data(X_train, X_test, y_train, y_test)
    df_renew = add_lags(df_renew, lag_vers=lag_vers)
    
    # split into test train again
    X, y = df_renew[df_renew.columns[:-1]], df_renew[df_renew.columns[-1]]
    cutoff = int(X.shape[0] * train_split)
    X_train, y_train = X[:cutoff], y[:cutoff]
    X_test, y_test = X[cutoff:], y[cutoff:]

    # display shapes
    print('='*65)
    print('New Training Set')
    print('Training Set Dims: {}'.format(X_train.shape))
    print('Testing Set Dims:  {}'.format(X_test.shape))
    print('='*65)

    return X_train, X_test, y_train, y_test

# %%
# function to prep data and return DF for modeling

def prepare_data(lag_vers=1, train_split=0.7, close_o=False, 
                         first_day=None, rescale=True, k_feat_perc=None):
    # read in  dataset and initialize output df
    df_in = get_data()
    
    # drop non-price fields if needed
    if close_o:
        df_in = keep_only_close(df_in)
    
    # add prediction field
    df_in = add_prediction_field(df_in)
    
    # cut off prior to first_day
    if first_day:
        df_in = truncate_date(df_in, first_day)
    
    return create_training_data(df_in, lag_vers=lag_vers, train_split=train_split, 
                                rescale=rescale, k_feat_perc=k_feat_perc)

# %% [markdown]
# ## Preparing Data for Training

# %%
# split dataset
X_train, X_test, y_train, y_test = prepare_data(lag_vers=2, train_split=0.8, close_o=False, 
                                    first_day='2016-1-1', rescale=True, k_feat_perc=50)
# Out:
# =================================================================
# New Training Set
# Training Set Dims: (812, 240)
# Testing Set Dims:  (203, 240)
# =================================================================

# %%
X_train.shape
# Out:
# (812, 240)

# %%
X_test.shape
# Out:
# (203, 240)

# %%
y_train.shape
# Out:
# (812,)

# %%
y_test.shape
# Out:
# (203,)

# %%
# balance of dependent variable values
ones = y_train.sum()
zeros = y_train.shape[0] - ones
print("0's: {}".format(zeros))
print("1's: {}".format(ones))
# Out:
# 0's: 334
# 1's: 478

# %%
# balance of dependent variable values
ones = y_test.sum()
zeros = y_test.shape[0] - ones
print("0's: {}".format(zeros))
print("1's: {}".format(ones))
# Out:
# 0's: 96
# 1's: 107

# %% [markdown]
# ## Build, Train, Test SOFNN Model

# %%
# function to create and train model

def run_model(rules=5, batch_size = 1, epochs=5):
    # get shape of training data
    samples, feats = X_train.shape
    
    # add layers
    inputs = Input(shape=(feats,))
    fuzz = FuzzyLayer(rules)
    norm = NormalizedLayer(rules)
    weights = WeightedLayer(rules)
    
    # run through layers
    phi = fuzz(inputs)
    phi = norm(phi)
    phi = weights([inputs, phi])
    preds = Dense(1, activation='linear',use_bias=False)(phi)
    
    # compile model and output summary 
    model = Model(inputs=inputs, outputs=preds)
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    print(model.summary())
    
    # fit model and evaluate
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,shuffle=False)
    scores = model.evaluate(X_test, y_test, verbose=2)
    accuracy = scores[1] * 100
    print("\nAccuracy: {:.2f}%".format(accuracy))
    
    # print confusion matrix
    print('\nConfusion Matrix')
    print('='*20)
    y_pred = np.squeeze(np.round(model.predict(X_test)), axis=-1)
    print(pd.DataFrame(confusion_matrix(y_test, y_pred), 
                       index=['true:no', 'true:yes'], columns=['pred:no', 'pred:yes']))
    
    # print classification report
    print('\nClasification Report')
    print('='*20)
    print(classification_report(y_test, y_pred, labels=[0,1]))
    
    return model

# %%
# test out various nodes
for rule in [5]:
    print('{} Rules'.format(rule))
    model = run_model(rules=rule, batch_size=30, epochs=5)
# Out:
# 5 Rules
# Inputs
# x shape: (?, 240)
# phi shape: (?, 5)
#
# Intermediates
# al_b shape: (?, 241)
# al_a.T shape: (241, 5)
#
# Output weight
# w2 shape: (?, 5)
# phi shape: (?, 5)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 240)          0
# __________________________________________________________________________________________________
# fuzzy_layer_3 (FuzzyLayer)      (None, 5)            2400        input_3[0][0]
# __________________________________________________________________________________________________
# normalized_layer_3 (NormalizedL (None, 5)            0           fuzzy_layer_3[0][0]
# __________________________________________________________________________________________________
# weighted_layer_3 (WeightedLayer (None, 5)            1205        input_3[0][0]
#                                                                  normalized_layer_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            5           weighted_layer_3[0][0]
# ==================================================================================================
# Total params: 3,610
# Trainable params: 3,610
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 812/812 [==============================] - 0s 516us/step - loss: 1.4795 - acc: 0.4298
# Epoch 2/5
# 812/812 [==============================] - 0s 142us/step - loss: 1.1640 - acc: 0.4310
# Epoch 3/5
# 812/812 [==============================] - 0s 138us/step - loss: 0.8777 - acc: 0.4581
# Epoch 4/5
# 812/812 [==============================] - 0s 128us/step - loss: 0.7943 - acc: 0.4594
# Epoch 5/5
# 812/812 [==============================] - 0s 130us/step - loss: 0.7439 - acc: 0.4852
#
# Accuracy: 48.77%
#
# Confusion Matrix
# ====================
#           pred:no  pred:yes
# true:no        61        35
# true:yes       69        38
#
# Clasification Report
# ====================
#               precision    recall  f1-score   support
#
#            0       0.47      0.64      0.54        96
#            1       0.52      0.36      0.42       107
#
#    micro avg       0.49      0.49      0.49       203
#    macro avg       0.49      0.50      0.48       203
# weighted avg       0.50      0.49      0.48       203
